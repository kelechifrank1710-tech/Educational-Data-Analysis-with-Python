# %%
# Educational Data Analysis with Python

## Notebook 2: Data Cleaning

##Author:** Kelechi Frank

### Objective

#The purpose of this notebook is to clean the dataset by identifying missing values, duplicate records, incorrect data types, and other quality issues before carrying out exploratory data analysis.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../datasets/Education_Student_Depression.csv")
df
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  \
# 0           2    Male   33  Visakhapatnam    Student                  5
# 1           8  Female   24      Bangalore    Student                  2
# 2          26    Male   31       Srinagar    Student                  3
# 3          30  Female   28       Varanasi    Student                  3
# 4          32  Female   25         Jaipur    Student                  4
# ...       ...     ...  ...            ...        ...                ...
# 27896  140685  Female   27          Surat    Student                  5
# 27897  140686    Male   27       Ludhiana    Student                  2
# 27898  140689    Male   31      Faridabad    Student                  3
# 27899  140690  Female   18       Ludhiana    Student                  5
# 27900  140699    Male   27          Patna    Student                  4
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
#check for missing values in each cell and  and counts how many missing values each column has
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
### Observation

#The output above shows the number of missing values in each column. Columns with missing values may require cleaning before analysis.

# %%
#how many rows appear more than once 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
### Observation

#Duplicate records can affect the accuracy of data analysis. The output above indicates whether duplicate rows exist in the dataset.

# %%
df.drop_duplicates()
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  \
# 0           2    Male   33  Visakhapatnam    Student                  5
# 1           8  Female   24      Bangalore    Student                  2
# 2          26    Male   31       Srinagar    Student                  3
# 3          30  Female   28       Varanasi    Student                  3
# 4          32  Female   25         Jaipur    Student                  4
# ...       ...     ...  ...            ...        ...                ...
# 27896  140685  Female   27          Surat    Student                  5
# 27897  140686    Male   27       Ludhiana    Student                  2
# 27898  140689    Male   31      Faridabad    Student                  3
# 27899  140690  Female   18       Ludhiana    Student                  5
# 27900  140699    Male   27          Patna    Student                  4
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.shape
# Out:
# (27901, 18)

# %%
### Observation

#The dataset shape confirms the number of rows and columns after removing duplicate records.

# %%
#check the data types
df.dtypes
# Out:
# id                                         int64
# Gender                                    object
# Age                                        int64
# City                                      object
# Profession                                object
# Academic Pressure                          int64
# Work Pressure                              int64
# CGPA                                     float64
# Study Satisfaction                         int64
# Job Satisfaction                           int64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                           int64
# Financial Stress                         float64
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %%
### Observation

#Understanding the data type of each variable helps determine the appropriate analysis and whether any columns require conversion.

# %%
#save cleaned data
df.to_csv("../datasets/Education_Student_Depression_Cleaned.csv", index = False)
